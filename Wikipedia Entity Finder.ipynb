# %%
	
pip install wikipedia
# Out:
# Requirement already satisfied: wikipedia in /srv/conda/envs/notebook/lib/python3.6/site-packages (1.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from wikipedia) (2.26.0)
# Requirement already satisfied: beautifulsoup4 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from wikipedia) (4.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.1)
# Requirement already satisfied: soupsieve>1.2 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from beautifulsoup4->wikipedia) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
	
import wikipedia

# %%
wikipedia.set_lang("en")

# %%
wikipedia.search("probate")
# Out:
# ['Probate',
#  'Probate court',
#  'High Court of Justice',
#  'Probate sale',
#  'Uniform Probate Code',
#  'Will and testament',
#  'National Probate Calendar',
#  'Administration (probate law)',
#  'Estate planning',
#  'President of the Family Division']

# %%
wikipedia.page("'Probate'").content
# Out:
# 'Probate is the judicial process whereby a will is "proved" in a court of law and accepted as a valid public document that is the true last testament of the deceased, or whereby the estate is settled according to the laws of intestacy in the state of residence of the deceased at time of death in the absence of a legal will.\nThe granting of probate is the first step in the legal process of administering the estate of a deceased person, resolving all claims and distributing the deceased person\'s property under a will. A probate court decides the legal validity of a testator\'s (deceased person\'s) will and grants its approval, also known as granting probate, to the executor. The probated will then becomes a legal instrument that may be enforced by the executor in the law courts if necessary. A probate also officially appoints the executor (or personal representative), generally named in the will, as having legal power to dispose of the testator\'s assets in the manner specified in the testator\'s will. However, through the probate process, a will may be contested.\n\n\n== Terminology ==\n\n\n=== Executor ===\n\nAn executor is a person appointed by a will to act on behalf of the estate of the will-maker (the "testator") upon his or her death. An executor is the legal personal representative of a deceased person\'s estate. The appointment of an executor only becomes effective after the death of the testator. After the testator dies, the person named in the will as executor can decline or renounce the position, and if so should quickly notify the probate court accordingly.\nExecutors "step into the shoes" of the deceased and have similar rights and powers to wind up the personal affairs of the deceased. This may include continuing or filing lawsuits that the deceased was entitled to bring, making claims for wrongful death, paying off creditors, or selling or disposing of assets not particularly gifted in the will, among others. But the role of the executor is to resolve the testator\'s estate and to distribute the estate to the beneficiaries or those otherwise entitled.\nSometimes, in England and Wales, a professional executor is named in the will – not a family member but (for example) a solicitor, bank or other financial institution. Professional executors will charge the estate for carrying out duties related to the administration of the estate; this can leave the family facing additional costs. It is possible to get a professional executor to renounce their role, meaning they will have no part in dealing with the estate; or to reserve their power, which means the remaining executors will carry out the related duties, but without the involvement of the professional executor.\n\n\n=== Administrator ===\nWhen a person dies without a will then the legal personal representative is known as the "administrator".\nThis is commonly the closest relative, although that person can renounce their right to be administrator in which case the right moves to the next closest relative. This often happens when parents or grandparents are first in line to become the administrator but renounce their rights as they are old, don\'t have knowledge of estate law and feel that someone else is better suited to the task.The appointment of an administrator follows a codified list establishing priority appointees. Classes of persons named higher on the list receive priority of appointment to those lower on the list. Although relatives of the deceased frequently receive priority over all others, creditors of the deceased and \'any other citizen [of that jurisdiction]\' may act as an administrator if there is some cognizable reason or relationship to the estate. Alternatively, if no other person qualifies or no other person accepts appointment, the court will appoint a representative from the local public administrator\'s office.\n\n\n=== Probate clause ===\nA representative example of a complete probate clause, from the 14th century (or earlier) onwards, a ...

# %%
# !python -m spacy download en
# Out:
# ⚠ As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the
# full pipeline package name 'en_core_web_sm' instead.
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
#      |████████████████████████████████| 13.9 MB 12.2 MB/s
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from en-core-web-sm==3.2.0) (3.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.62.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.7.5)
# Requirement already satisfied: pathy>=0.3.5 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.26.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.13)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: numpy>=1.15.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.19.5)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (58.0.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.3)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.10.0.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.0)
# Requirement already satisfied: jinja2 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.9.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: dataclasses<1.0,>=0.6 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.8)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.0)
# Requirement already satisfied: contextvars<3,>=2.4 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from thinc<8.1.0,>=8.0.12->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.1)
# Requirement already satisfied: importlib-metadata in /srv/conda/envs/notebook/lib/python3.6/site-packages (from click<9.0.0,>=7.1.1->typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.8.1)
# Requirement already satisfied: immutables>=0.9 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from contextvars<3,>=2.4->thinc<8.1.0,>=8.0.12->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.16)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.2.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in /srv/conda/envs/notebook/lib/python3.6/site-packages (3.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (2.26.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (1.8.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: numpy>=1.15.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (1.19.5)
# Requirement already satisfied: pathy>=0.3.5 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (0.6.1)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (21.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (8.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (3.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (1.0.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (0.7.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (2.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (2.0.6)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (3.10.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (0.4.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (2.4.2)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (58.0.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (4.62.3)
# Requirement already satisfied: jinja2 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (3.0.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spacy) (1.0.6)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from catalogue<2.1.0,>=2.0.6->spacy) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from packaging>=20.0->spacy) (3.0.6)
# Requirement already satisfied: dataclasses<1.0,>=0.6 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from pathy>=0.3.5->spacy) (0.8)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.5.30)
# Requirement already satisfied: contextvars<3,>=2.4 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from thinc<8.1.0,>=8.0.12->spacy) (2.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from jinja2->spacy) (2.0.1)
# Requirement already satisfied: importlib-metadata in /srv/conda/envs/notebook/lib/python3.6/site-packages (from click<9.0.0,>=7.1.1->typer<0.5.0,>=0.3.0->spacy) (4.8.1)
# Requirement already satisfied: immutables>=0.9 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from contextvars<3,>=2.4->thinc<8.1.0,>=8.0.12->spacy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy

# %%
NER = spacy.load("en_core_web_sm")

# %%
text= NER(wikipedia.page("'Probate'").content)

# %%
for w in text.ents:
    print(w.text,w.label_)
# Out:
# first ORDINAL
# England GPE
# Wales GPE
# first ORDINAL
# the 14th century DATE
# Anthony Bathurst PERSON
# 1697 DATE
# PROB ORG
# 11/438 CARDINAL
# viro PERSON
# Richardo Raines PERSON
# legum doctore PERSON
# curiae praerogativae  Cantuariensis PERSON
# vicesimo GPE
# Junii Anno Domini Millesimo PERSON
# Nonaginta Septimo PERSON
# Mariae Bathurst PERSON
# executricis PERSON
# dicto GPE
# Dei Evangelis GPE
# Examinatur PERSON
# London GPE
# Richard Raines PERSON
# Keeper PERSON
# the Prerogative Court of Canterbury ORG
# the twenty third day of the month of June DATE
# the year DATE
# Mary Bathurst PERSON
# English NORP
# Latin NORP
# many centuries DATE
# Latin LANGUAGE
# Probatum Londini PERSON
# viro PERSON
# legum doctore curiae PERSON
# Cantuariensis PERSON
# London GPE
# the Prerogative Court of Canterbury ORG
# English NORP
# 1463 DATE
# Latin NORP
# English LANGUAGE
# US GPE
# Homestead PERSON
# Florida GPE
# Canada GPE
# US GPE
# UK GPE
# Australia GPE
# India GPE
# Australia GPE
# Australia GPE
# Supreme Court ORG
# South Wales GPE
# 1898 DATE
# 1958 DATE
# 1981 DATE
# Australia GPE
# 1967 DATE
# South Australia GPE
# 1919 DATE
# Tasmania—Administration ORG
# 1935 DATE
# Australian Capital Territory PERSON
# 1929 DATE
# Northern Territory PERSON
# 1993 DATE
# 50,000 MONEY
# Australian NORP
# United Kingdom GPE
# England GPE
# Wales GPE
# English LANGUAGE
# the Wills Act 1837 LAW
# the Court of Chancery ORG
# 1873 DATE
# the Chancery Division of the High Court ORG
# English LANGUAGE
# the Chancery Division of the High Court of Justice ORG
# Section 25 LAW
# 1981 DATE
# The High Court ORG
# the Probate Registries WORK_OF_ART
# the High Court ORG
# two CARDINAL
# Latin NORP
# less than £5,000.00 MONEY
# One CARDINAL
# the Probate Division of the High Court ORG
# about £15,000 MONEY
# England GPE
# Wales GPE
# Administration ORG
# six months DATE
# the Inheritance (Provision for Family and Dependants ORG
# 1975 DATE
# eight days DATE
# Scotland GPE
# Scotland GPE
# two CARDINAL
# Scottish NORP
# United States GPE
# the United States GPE
# California GPE
# Probate ORG
# U.S. GPE
# U.S. GPE
# Hawaii GPE
# Latin NORP
# the United States GPE
# Calendar PERSON
# Encyclopædia Britannica PERSON
# 11th ed. DATE
# 1911 DATE

# %%
spacy.displacy.render(text, style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Probate is the judicial process whereby a will is &quot;proved&quot; in a court of law and accepted as a valid public document that is the true last testament of the deceased, or whereby the estate is settled according to the laws of intestacy in the state of residence of the deceased at time of death in the absence of a legal will.</br>The granting of probate is the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  step in the legal process of administering the estate of a deceased person, resolving all claims and distributing the deceased person's property under a will. A probate court decides the legal validity of a testator's (deceased person's) will and grants its approval, also known as granting probate, to the executor. The probated will then becomes a legal instrument that may be enforced by the executor in the law courts if necessary. A probate also officially appoints the executor (or personal representative), generally named in the will, as having legal power to dispose of the testator's assets in the manner specified in the testator's will. However, through the probate process, a will may be contested.</br></br></br>== Terminology ==</br></br></br>=== Executor ===</br></br>An executor is a person appointed by a will to act on behalf of the estate of the will-maker (the &quot;testator&quot;) upon his or her death. An executor is the legal personal representative of a deceased person's estate. The appointment of an executor only becomes effective after the death of the testator. After the testator dies, the person named in the will as executor can decline or renounce the position, and if so should quickly notify the probate court accordingly.</br>Executors &quot;step into the shoes&quot; of the deceased and have similar rights and powers to wind up the personal affairs of the deceased. This may include continuing or filing lawsuits that the deceased was entitled to bring, making claims for wrongful death, paying off creditors, or selling or disposing of assets not particularly gifted in the will, among others. But the role of the executor is to resolve the testator's estate and to distribute the estate to the beneficiaries or those otherwise entitled.</br>Sometimes, in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     England
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wales
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , a professional executor is named in the will – not a family member but (for example) a solicitor, bank or other financial institution. Professional executors will charge the estate for carrying out duties related to the administration of the estate; this can leave the family facing additional costs. It is possible to get a professional executor to renounce their role, meaning they will have no part in dealing with the estate; or to reserve their power, which means the remaining executors will carry out the related duties, but without the involvement of the professional executor.</br></br></br>=== Administrator ===</br>When a person dies without a will then the legal personal representative is known as the &quot;administrator&quot;.</br>This is commonly the closest relative, although that person can renounce their right to be administrator in which case the right moves to the next closest relative. This often happens when parents or grandparents are
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  in line to become the administrator but renounce their rights as they are old, don't have knowledge of estate law and feel that someone else is better suited to the task.The appointment of an administrator follows a codified list establishing priority appointees. Classes of persons named higher on the list receive priority of appointment to those lower on the list. Although relatives of the deceased frequently receive priority over all others, creditors of the deceased and 'any other citizen [of that jurisdiction]' may act as an administrator if there is some cognizable reason or relationship to the estate. Alternatively, if no other person qualifies or no other person accepts appointment, the court will appoint a representative from the local public administrator's office.</br></br></br>=== Probate clause ===</br>A representative example of a complete probate clause, from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 14th century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (or earlier) onwards, added at the bottom of the office transcribed copy of a will is as follows, taken from the will of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anthony Bathurst
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1697
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PROB
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11/438
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# :</br></br>PROBATUM fuit huiusmodi testamentum apud Londinium coram  venerabili et egregio
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     viro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  domino
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Richardo Raines
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , milite,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     legum doctore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
